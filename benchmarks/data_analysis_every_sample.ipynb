# %%
import pandas as pd

# %%
evaluation_data = pd.read_csv('./results/benchmark_generating_every_sample_without_cache.csv')

# %%
evaluation_data.tail(10)
# Out:
#    Algorithm  Samples  Generation Time  Sample Time
# 10  Outlines      160         1.258106    45.249031
# 11      ASMR      160         8.460717     0.028756
# 12  Outlines      320         1.257279    94.741067
# 13      ASMR      320         8.854399     0.057931
# 14  Outlines      640         1.298440   187.290572
# 15      ASMR      640         8.491418     0.099716
# 16  Outlines     1280         1.268269   367.537990
# 17      ASMR     1280         8.786053     0.200540
# 18  Outlines     2560         1.274022   750.240107
# 19      ASMR     2560         8.585877     0.418590

# %%
evaluation_data['Time'] = evaluation_data['Generation Time'] + evaluation_data['Sample Time']
evaluation_data
# Out:
#    Algorithm  Samples  Generation Time  Sample Time        Time
# 0   Outlines        5         7.790239     2.140211    9.930450
# 1       ASMR        5         8.558519     0.001446    8.559966
# 2   Outlines       10         1.250049     2.501351    3.751400
# 3       ASMR       10         8.683463     0.002134    8.685597
# 4   Outlines       20         1.408450    10.919863   12.328314
# 5       ASMR       20         8.932395     0.005148    8.937542
# 6   Outlines       40         1.272452    11.364985   12.637436
# 7       ASMR       40         8.616323     0.007868    8.624192
# 8   Outlines       80         1.267605    24.197798   25.465402
# 9       ASMR       80         8.416469     0.015160    8.431629
# 10  Outlines      160         1.258106    45.249031   46.507138
# 11      ASMR      160         8.460717     0.028756    8.489473
# 12  Outlines      320         1.257279    94.741067   95.998346
# 13      ASMR      320         8.854399     0.057931    8.912330
# 14  Outlines      640         1.298440   187.290572  188.589011
# 15      ASMR      640         8.491418     0.099716    8.591134
# 16  Outlines     1280         1.268269   367.537990  368.806259
# 17      ASMR     1280         8.786053     0.200540    8.986593
# 18  Outlines     2560         1.274022   750.240107  751.514130
# 19      ASMR     2560         8.585877     0.418590    9.004467

# %%
import seaborn as sns

sns.set_style("whitegrid")
ax = sns.lmplot(x="Samples", y="Time", hue="Algorithm",
                 data=evaluation_data, legend = True, legend_out = False, order = 2, ci=None, height = 6)
ax.axes[0,0].set_xlabel("Samples", fontsize = 12)
ax.axes[0,0].set_ylabel("Time", fontsize = 12)
ax.axes[0,0].set_title("Generation + Sample Time", fontsize = 12)
# Out:
# /home/yoni/miniconda3/envs/py37/lib/python3.7/site-packages/seaborn/regression.py:582: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1, 'Generation + Sample Time')

# %%
sns.set_style("whitegrid")

ax = sns.lmplot(x="Samples", y="Sample Time", hue="Algorithm",
                 data=evaluation_data, legend = True, legend_out = False, order = 2, ci=None, height = 6)
ax.axes[0,0].set_xlabel("Samples", fontsize = 12)
ax.axes[0,0].set_ylabel("Time", fontsize = 12)
ax.axes[0,0].set_title("Sample Time", fontsize = 12)
# Out:
# /home/yoni/miniconda3/envs/py37/lib/python3.7/site-packages/seaborn/regression.py:582: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1, 'Sample Time')

# %%
sns.set_style("whitegrid")

ax = sns.lmplot(x="Samples", y="Generation Time", hue="Algorithm",
                 data=evaluation_data, legend = True, legend_out = False, order = 1, ci=None, height = 6)
ax.axes[0,0].set_xlabel("Samples", fontsize = 12)
ax.axes[0,0].set_ylabel("Time", fontsize = 12)
ax.axes[0,0].set_title("Generation Time", fontsize = 12)
# Out:
# /home/yoni/miniconda3/envs/py37/lib/python3.7/site-packages/seaborn/regression.py:582: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1, 'Generation Time')
