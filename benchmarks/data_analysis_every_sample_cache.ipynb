# %%
import pandas as pd

# %%
evaluation_data = pd.read_csv('./results/benchmark_generating_every_sample_with_cache.csv')

# %%
evaluation_data.tail(10)
# Out:
#    Algorithm  Samples  Generation Time  Sample Time
# 10  Outlines      160         0.071912    58.345087
# 11      ASMR      160         8.477966     0.032603
# 12  Outlines      320         0.072256    93.079328
# 13      ASMR      320         8.924675     0.056827
# 14  Outlines      640         0.072765   187.648651
# 15      ASMR      640         8.510853     0.103347
# 16  Outlines     1280         0.086560   384.603140
# 17      ASMR     1280         8.620610     0.220467
# 18  Outlines     2560         0.072643   784.360726
# 19      ASMR     2560         9.202711     0.427317

# %%
evaluation_data['Time'] = evaluation_data['Generation Time'] + evaluation_data['Sample Time']
evaluation_data
# Out:
#    Algorithm  Samples  Generation Time  Sample Time        Time
# 0   Outlines        5         7.849760     2.174207   10.023967
# 1       ASMR        5         8.693572     0.001166    8.694738
# 2   Outlines       10         0.059815     2.914451    2.974266
# 3       ASMR       10         8.612983     0.002216    8.615199
# 4   Outlines       20         0.079486     6.337277    6.416763
# 5       ASMR       20         9.053924     0.005022    9.058945
# 6   Outlines       40         0.074189    12.705176   12.779366
# 7       ASMR       40         9.113093     0.010187    9.123280
# 8   Outlines       80         0.070175    22.284210   22.354384
# 9       ASMR       80         8.683428     0.015771    8.699199
# 10  Outlines      160         0.071912    58.345087   58.417000
# 11      ASMR      160         8.477966     0.032603    8.510569
# 12  Outlines      320         0.072256    93.079328   93.151584
# 13      ASMR      320         8.924675     0.056827    8.981502
# 14  Outlines      640         0.072765   187.648651  187.721416
# 15      ASMR      640         8.510853     0.103347    8.614200
# 16  Outlines     1280         0.086560   384.603140  384.689699
# 17      ASMR     1280         8.620610     0.220467    8.841077
# 18  Outlines     2560         0.072643   784.360726  784.433369
# 19      ASMR     2560         9.202711     0.427317    9.630028

# %%
import seaborn as sns

sns.set_style("whitegrid")
ax = sns.lmplot(x="Samples", y="Time", hue="Algorithm",
                 data=evaluation_data, legend = True, legend_out = False, order = 2, ci=None, height = 6)
ax.axes[0,0].set_xlabel("Samples", fontsize = 12)
ax.axes[0,0].set_ylabel("Time", fontsize = 12)
ax.axes[0,0].set_title("Generation + Sample Time", fontsize = 12)
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /home/yoni/miniconda3/envs/py37/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution
# /home/yoni/miniconda3/envs/py37/lib/python3.7/site-packages/seaborn/regression.py:582: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1, 'Generation + Sample Time')

# %%
sns.set_style("whitegrid")

ax = sns.lmplot(x="Samples", y="Sample Time", hue="Algorithm",
                 data=evaluation_data, legend = True, legend_out = False, order = 2, ci=None, height = 6)
ax.axes[0,0].set_xlabel("Samples", fontsize = 12)
ax.axes[0,0].set_ylabel("Time", fontsize = 12)
ax.axes[0,0].set_title("Sample Time", fontsize = 12)
# Out:
# /home/yoni/miniconda3/envs/py37/lib/python3.7/site-packages/seaborn/regression.py:582: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1, 'Sample Time')

# %%
sns.set_style("whitegrid")

ax = sns.lmplot(x="Samples", y="Generation Time", hue="Algorithm",
                 data=evaluation_data, legend = True, legend_out = False, order = 1, ci=None, height = 6)
ax.axes[0,0].set_xlabel("Samples", fontsize = 12)
ax.axes[0,0].set_ylabel("Time", fontsize = 12)
ax.axes[0,0].set_title("Generation Time", fontsize = 12)
# Out:
# /home/yoni/miniconda3/envs/py37/lib/python3.7/site-packages/seaborn/regression.py:582: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1, 'Generation Time')
