# %%
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load data from experiment

# %%
evaluation_data = pd.read_csv('./results/results_05_03_2023_23_39_41.csv')

# %% [markdown]
# ### Data analyisis

# %%
len(evaluation_data)
# Out:
# 4

# %%
evaluation_data.head(16)
# Out:
#    Unnamed: 0                 Algorithm  Instance  Number of Extracted States  \
# 0           0         BoundedQuant_top1       NaN                          79
# 1           1         BoundedQuant_rank       NaN                         299
# 2           2  BoundedQuant_quantizaion       NaN                         811
# 3           3    BoundedQuant_ta_geq_gc       NaN                          54
#
#    RunNumber    Time (s)  LastTokenQuery  EquivalenceQuery  \
# 0          0   65.569739             870                55
# 1          0  130.252451             850                96
# 2          0  327.996372             740               102
# 3          0   71.050788             880                54
#
#    NumberOfStatesExceeded  QueryLengthExceeded  TimeExceeded  Tree Depth  \
# 0                   False                False         False           9
# 1                   False                False         False           5
# 2                   False                False         False           5
# 3                   False                False         False          12
#
#    Inner Nodes  TimeBound  Accuracy  Unknown Results Percentage
# 0           23       1000     1.000                         0.0
# 1           19       1000     1.000                         0.0
# 2           17       1000     1.000                         0.0
# 3           32       1000     0.998                         0.0

# %%
evaluation_data['Total_Acc'] = evaluation_data['Accuracy']*(1-evaluation_data['Unknown Results Percentage'])

# %%
evaluation_data.head(16)
# Out:
#    Unnamed: 0                 Algorithm  Instance  Number of Extracted States  \
# 0           0         BoundedQuant_top1       NaN                          79
# 1           1         BoundedQuant_rank       NaN                         299
# 2           2  BoundedQuant_quantizaion       NaN                         811
# 3           3    BoundedQuant_ta_geq_gc       NaN                          54
#
#    RunNumber    Time (s)  LastTokenQuery  EquivalenceQuery  \
# 0          0   65.569739             870                55
# 1          0  130.252451             850                96
# 2          0  327.996372             740               102
# 3          0   71.050788             880                54
#
#    NumberOfStatesExceeded  QueryLengthExceeded  TimeExceeded  Tree Depth  \
# 0                   False                False         False           9
# 1                   False                False         False           5
# 2                   False                False         False           5
# 3                   False                False         False          12
#
#    Inner Nodes  TimeBound  Accuracy  Unknown Results Percentage  Total_Acc
# 0           23       1000     1.000                         0.0      1.000
# 1           19       1000     1.000                         0.0      1.000
# 2           17       1000     1.000                         0.0      1.000
# 3           32       1000     0.998                         0.0      0.998
