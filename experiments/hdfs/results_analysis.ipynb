# %%
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load data from experiment

# %%
evaluation_data = pd.read_csv('./results/results_04_03_2023_00_21_47.csv')

# %% [markdown]
# ### Data analyisis

# %%
evaluation_data.head(16).sort_values('Number of Extracted States')#[['Algorithm','Unknown Results Percentage','Accuracy']]
# Out:
#    Unnamed: 0                 Algorithm  Instance  Number of Extracted States  \
# 6           6       BoundedQuant_quant3       NaN                         660
# 5           5         BoundedQuant_top3       NaN                        1616
# 3           3        BoundedQuant_rank3       NaN                        2008
# 0           0         BoundedQuant_top6       NaN                        2087
# 4           4       BoundedQuant_quant5       NaN                        3014
# 2           2  BoundedQuant_quantizaion       NaN                        7289
# 1           1         BoundedQuant_rank       NaN                        8837
#
#    RunNumber      Time (s)  LastTokenQuery  EquivalenceQuery  \
# 6          0  10020.584198           33840               326
# 5          0  10015.758222            6750               153
# 3          0  10012.904841            3900               105
# 0          0  10012.339888            3390                87
# ...

# %%
evaluation_data['Total_Acc'] = evaluation_data['Accuracy']*(1-evaluation_data['Unknown Results Percentage'])

# %%
evaluation_data.head(16).sort_values('Number of Extracted States')
# Out:
#    Unnamed: 0                 Algorithm  Instance  Number of Extracted States  \
# 6           6       BoundedQuant_quant3       NaN                         660
# 5           5         BoundedQuant_top3       NaN                        1616
# 3           3        BoundedQuant_rank3       NaN                        2008
# 0           0         BoundedQuant_top6       NaN                        2087
# 4           4       BoundedQuant_quant5       NaN                        3014
# 2           2  BoundedQuant_quantizaion       NaN                        7289
# 1           1         BoundedQuant_rank       NaN                        8837
#
#    RunNumber      Time (s)  LastTokenQuery  EquivalenceQuery  \
# 6          0  10020.584198           33840               326
# 5          0  10015.758222            6750               153
# 3          0  10012.904841            3900               105
# 0          0  10012.339888            3390                87
# ...
