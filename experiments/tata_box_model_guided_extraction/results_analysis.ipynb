# %%
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install tensorflow==2.12.0
# Out:
# ^C
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\franz\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\franz\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\franz\appdata\roaming\python\python39\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\franz\appdata\roaming\python\python39\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Acceso denegado: 'C:\\Users\\franz\\AppData\\Roaming\\Python\\Python39\\site-packages\\~umpy\\.libs\\libopenblas64__v0.3.21-gcc_10_3_0.dll'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\franz\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\franz\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\franz\appdata\roaming\python\python39\site-packages)
# Collecting tensorflow==2.12.0
#   Downloading tensorflow-2.12.0-cp39-cp39-win_amd64.whl (1.9 kB)
# Collecting tensorflow-intel==2.12.0
#   Downloading tensorflow_intel-2.12.0-cp39-cp39-win_amd64.whl (272.8 MB)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (16.0.0)
# Collecting keras<2.13,>=2.12.0
#   Downloading keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.4.0)
# Collecting jax>=0.3.15
#   Downloading jax-0.4.23-py3-none-any.whl (1.7 MB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.31.0)
# Collecting numpy<1.24,>=1.22
#   Downloading numpy-1.23.5-cp39-cp39-win_amd64.whl (14.7 MB)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\franz\anaconda3\envs\pymodelextractor_exp\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.13.3)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.2.0)
# Collecting tensorflow-estimator<2.13,>=2.12.0
#   Downloading tensorflow_estimator-2.12.0-py2.py3-none-any.whl (440 kB)
# Requirement already satisfied: packaging in c:\users\franz\anaconda3\envs\pymodelextractor_exp\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (21.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.16.0)
# Collecting tensorboard<2.13,>=2.12
#   Downloading tensorboard-2.12.3-py3-none-any.whl (5.6 MB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (4.6.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (4.25.1)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.8.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.54.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.6.3)
# Requirement already satisfied: setuptools in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (67.8.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.3.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.4.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (23.5.26)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\franz\appdata\roaming\python\python39\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.40.0)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\franz\appdata\roaming\python\python39\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow==2.12.0) (6.6.0)
# Collecting scipy>=1.9
#   Downloading scipy-1.11.4-cp39-cp39-win_amd64.whl (44.3 MB)
# Collecting ml-dtypes>=0.2.0
#   Using cached ml_dtypes-0.3.1-cp39-cp39-win_amd64.whl (126 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\franz\appdata\roaming\python\python39\site-packages (from importlib-metadata>=4.6->jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.15.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.4.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.0.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.19.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.3.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\franz\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\franz\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\franz\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (5.3.1)
# Requirement already satisfied: urllib3<2.0 in c:\users\franz\anaconda3\envs\pymodelextractor_exp\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.26.15)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\franz\appdata\roaming\python\python39\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.3.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\franz\appdata\roaming\python\python39\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\franz\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\franz\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\franz\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\franz\appdata\roaming\python\python39\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\franz\appdata\roaming\python\python39\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.1.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\franz\appdata\roaming\python\python39\site-packages (from packaging->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.4.7)
# Installing collected packages: numpy, scipy, ml-dtypes, tensorflow-estimator, tensorboard, keras, jax, tensorflow-intel, tensorflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
# Collecting tensorflow==2.12.0
#   Using cached tensorflow-2.12.0-cp39-cp39-win_amd64.whl (1.9 kB)
# Collecting tensorflow-intel==2.12.0
#   Using cached tensorflow_intel-2.12.0-cp39-cp39-win_amd64.whl (272.8 MB)
# Collecting tensorflow-estimator<2.13,>=2.12.0
#   Using cached tensorflow_estimator-2.12.0-py2.py3-none-any.whl (440 kB)
# Requirement already satisfied: six>=1.12.0 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (4.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (23.5.26)
# Collecting tensorboard<2.13,>=2.12
#   Using cached tensorboard-2.12.3-py3-none-any.whl (5.6 MB)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.2.0)
# Collecting numpy<1.24,>=1.22
#   Using cached numpy-1.23.5-cp39-cp39-win_amd64.whl (14.7 MB)
# Collecting keras<2.13,>=2.12.0
#   Using cached keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.4.0)
# Requirement already satisfied: setuptools in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (67.8.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\franz\anaconda3\envs\pymodelextractor_exp\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.13.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.54.2)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (16.0.0)
# Requirement already satisfied: packaging in c:\users\franz\anaconda3\envs\pymodelextractor_exp\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (21.3)
# Collecting jax>=0.3.15
#   Using cached jax-0.4.23-py3-none-any.whl (1.7 MB)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.4.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.8.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.12.0->tensorflow==2.12.0) (4.25.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\franz\appdata\roaming\python\python39\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.40.0)
# Collecting ml-dtypes>=0.2.0
#   Using cached ml_dtypes-0.3.1-cp39-cp39-win_amd64.whl (126 kB)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\franz\appdata\roaming\python\python39\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow==2.12.0) (6.6.0)
# Collecting scipy>=1.9
#   Using cached scipy-1.11.4-cp39-cp39-win_amd64.whl (44.3 MB)
# Requirement already satisfied: zipp>=0.5 in c:\users\franz\appdata\roaming\python\python39\site-packages (from importlib-metadata>=4.6->jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.15.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.4.3)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.31.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.19.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\franz\appdata\roaming\python\python39\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.7.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\franz\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (4.9)
# Requirement already satisfied: urllib3<2.0 in c:\users\franz\anaconda3\envs\pymodelextractor_exp\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.26.15)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\franz\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\franz\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (5.3.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\franz\appdata\roaming\python\python39\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (1.3.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\franz\appdata\roaming\python\python39\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (0.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\franz\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\franz\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\franz\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2023.5.7)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\franz\appdata\roaming\python\python39\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (3.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\franz\appdata\roaming\python\python39\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.1.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\franz\appdata\roaming\python\python39\site-packages (from packaging->tensorflow-intel==2.12.0->tensorflow==2.12.0) (2.4.7)
# Installing collected packages: numpy, scipy, ml-dtypes, tensorflow-estimator, tensorboard, keras, jax, tensorflow-intel, tensorflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Can't uninstall 'numpy'. No files were found to uninstall.
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.14.1
#     Uninstalling tensorboard-2.14.1:
#       Successfully uninstalled tensorboard-2.14.1
#   Attempting uninstall: keras
#     Found existing installation: keras 2.14.0
#     Uninstalling keras-2.14.0:
#       Successfully uninstalled keras-2.14.0
#   Attempting uninstall: tensorflow-intel
#     Found existing installation: tensorflow-intel 2.14.0
#     Uninstalling tensorflow-intel-2.14.0:
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\franz\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\franz\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\franz\appdata\roaming\python\python39\site-packages)
# WARNING: Error parsing requirements for numpy: [Errno 2] No such file or directory: 'c:\\users\\franz\\appdata\\roaming\\python\\python39\\site-packages\\numpy-1.24.3.dist-info\\METADATA'
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\franz\appdata\roaming\python\python39\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\franz\appdata\roaming\python\python39\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\franz\appdata\roaming\python\python39\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\franz\appdata\roaming\python\python39\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\franz\appdata\roaming\python\python39\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Acceso denegado: 'c:\\users\\franz\\appdata\\roaming\\python\\python39\\site-packages\\tensorflow\\compiler\\tf2tensorrt\\_pywrap_py_utils.pyd'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\franz\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\franz\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\franz\appdata\roaming\python\python39\site-packages)

# %% [markdown]
# ### Load data from experiment

# %%
evaluation_data = pd.read_csv('./results/results_09_03_2023_17_48_01.csv')

# %% [markdown]
# ### Data analyisis

# %%
len(evaluation_data)
# Out:
# 2

# %%
evaluation_data.head(16)
# Out:
#    Unnamed: 0          Algorithm Instance  Number of Extracted States  \
# 0           0  BoundedQuant_top1        B                           3
# 1           1  BoundedQuant_top1        T                           4
#
#    RunNumber    Time (s)  LastTokenQuery  EquivalenceQuery  \
# 0          0  154.084255            1536                 1
# 1          0  170.171171            1536                 1
#
#    NumberOfStatesExceeded  QueryLengthExceeded  TimeExceeded  Tree Depth  \
# 0                   False                False          True           1
# 1                   False                False          True           1
#
#    Inner Nodes  TimeBound  Accuracy  Unknown Results Percentage
# 0            1        120    0.8750                       0.992
# 1            1        120    0.8625                       0.920

# %%
evaluation_data['Total_Acc'] = evaluation_data['Accuracy']*(1-evaluation_data['Unknown Results Percentage'])

# %%
evaluation_data.head(16)
# Out:
#    Unnamed: 0          Algorithm Instance  Number of Extracted States  \
# 0           0  BoundedQuant_top3   BOTTOM                           3
# 1           1  BoundedQuant_top3      TOP                           3
#
#    RunNumber    Time (s)  LastTokenQuery  EquivalenceQuery  \
# 0          0  184.525117            1536                 1
# 1          0  176.163640            1536                 1
#
#    NumberOfStatesExceeded  QueryLengthExceeded  TimeExceeded  Tree Depth  \
# 0                   False                False          True           1
# 1                   False                False          True           1
#
#    Inner Nodes  TimeBound  Accuracy  Unknown Results Percentage  Total_Acc
# 0            1        120  0.325337                       0.333      0.217
# 1            1        120  0.528736                       0.913      0.046
