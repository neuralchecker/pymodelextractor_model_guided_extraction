# %%
import pandas as pd

# %%
evaluation_data = pd.read_csv('./results/benchmark_1_1709768506.8624783.csv')

# %%
evaluation_data.tail(10)
# Out:
#    Algorithm  Samples  Execution  Generation Time  Sample Time
# 2   Outlines       10          0        14.413557     9.180847
# 3       ASMR       10          0        24.477848     0.002898
# 4   Outlines        5          1        11.640069     7.144247
# 5       ASMR        5          1        26.724287     0.002933
# 6   Outlines       10          1        18.455381     8.742527
# 7       ASMR       10          1        21.031355     0.003072
# 8   Outlines        5          2        13.278916     8.316661
# 9       ASMR        5          2        30.614659     0.015277
# 10  Outlines       10          2        14.730731    10.981493
# 11      ASMR       10          2        21.294673     0.003333

# %%
evaluation_data['Time'] = evaluation_data['Generation Time'] + evaluation_data['Sample Time']
evaluation_data
# Out:
#    Algorithm  Samples  Execution  Generation Time  Sample Time       Time
# 0   Outlines        5          0        13.715202     5.717437  19.432639
# 1       ASMR        5          0        22.253562     0.004953  22.258515
# 2   Outlines       10          0        14.413557     9.180847  23.594404
# 3       ASMR       10          0        24.477848     0.002898  24.480746
# 4   Outlines        5          1        11.640069     7.144247  18.784316
# 5       ASMR        5          1        26.724287     0.002933  26.727221
# 6   Outlines       10          1        18.455381     8.742527  27.197908
# 7       ASMR       10          1        21.031355     0.003072  21.034427
# 8   Outlines        5          2        13.278916     8.316661  21.595577
# 9       ASMR        5          2        30.614659     0.015277  30.629936
# 10  Outlines       10          2        14.730731    10.981493  25.712224
# 11      ASMR       10          2        21.294673     0.003333  21.298006

# %%
import seaborn as sns

# %%
ax = sns.boxplot(x="Samples", y="Time", hue="Algorithm", data=evaluation_data)
ax.set_title('Generate + Sample Time')
# Out:
# Text(0.5, 1.0, 'Generate + Sample Time')

# %%
sns.set_style("whitegrid")
ax = sns.lmplot(x="Samples", y="Time", hue="Algorithm",
                 data=evaluation_data, legend = True, legend_out = False, order = 2, ci=None, height = 6)
ax.axes[0,0].set_xlabel("Samples", fontsize = 12)
ax.axes[0,0].set_ylabel("Time", fontsize = 12)
ax.axes[0,0].set_title("Generation + Sample Time", fontsize = 12)
# Out:
# /home/martin/miniconda3/envs/model_guided_extraction/lib/python3.9/site-packages/seaborn/regression.py:582: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
# /home/martin/miniconda3/envs/model_guided_extraction/lib/python3.9/site-packages/seaborn/regression.py:251: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /home/martin/miniconda3/envs/model_guided_extraction/lib/python3.9/site-packages/seaborn/regression.py:251: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# Text(0.5, 1.0, 'Generation + Sample Time')

# %%
sns.set_style("whitegrid")

ax = sns.lmplot(x="Samples", y="Sample Time", hue="Algorithm",
                 data=evaluation_data, legend = True, legend_out = False, order = 2, ci=None, height = 6)
ax.axes[0,0].set_xlabel("Samples", fontsize = 12)
ax.axes[0,0].set_ylabel("Time", fontsize = 12)
ax.axes[0,0].set_title("Sample Time", fontsize = 12)
# Out:
# /home/martin/miniconda3/envs/model_guided_extraction/lib/python3.9/site-packages/seaborn/regression.py:582: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
# /home/martin/miniconda3/envs/model_guided_extraction/lib/python3.9/site-packages/seaborn/regression.py:251: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# /home/martin/miniconda3/envs/model_guided_extraction/lib/python3.9/site-packages/seaborn/regression.py:251: RankWarning: Polyfit may be poorly conditioned
#   return np.polyval(np.polyfit(_x, _y, order), grid)
# Text(0.5, 1.0, 'Sample Time')

# %%
sns.set_style("whitegrid")

ax = sns.lmplot(x="Samples", y="Generation Time", hue="Algorithm",
                 data=evaluation_data, legend = True, legend_out = False, order = 1, ci=None, height = 6)
ax.axes[0,0].set_xlabel("Samples", fontsize = 12)
ax.axes[0,0].set_ylabel("Time", fontsize = 12)
ax.axes[0,0].set_title("Generation Time", fontsize = 12)
# Out:
# /home/martin/miniconda3/envs/model_guided_extraction/lib/python3.9/site-packages/seaborn/regression.py:582: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'Generation Time')
