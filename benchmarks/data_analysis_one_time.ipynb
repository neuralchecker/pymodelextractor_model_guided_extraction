# %%
import pandas as pd

# %%
evaluation_data = pd.read_csv('./results/benchmark_generating_one_time.csv')

# %%
evaluation_data.tail(10)
# Out:
#    Algorithm  Samples  Generation Time  Sample Time
# 10  Outlines      160         9.132346    43.143683
# 11      ASMR      160         8.933138     0.030442
# 12  Outlines      320         9.132346    89.036746
# 13      ASMR      320         8.933138     0.053871
# 14  Outlines      640         9.132346   195.216082
# 15      ASMR      640         8.933138     0.099088
# 16  Outlines     1280         9.132346   363.593692
# 17      ASMR     1280         8.933138     0.210480
# 18  Outlines     2560         9.132346   740.676609
# 19      ASMR     2560         8.933138     0.396044

# %%
evaluation_data['Time'] = evaluation_data['Generation Time'] + evaluation_data['Sample Time']
evaluation_data
# Out:
#    Algorithm  Samples  Generation Time  Sample Time        Time
# 0   Outlines        5         9.132346     1.753330   10.885675
# 1       ASMR        5         8.933138     0.001611    8.934748
# 2   Outlines       10         9.132346     3.110032   12.242378
# 3       ASMR       10         8.933138     0.002660    8.935797
# 4   Outlines       20         9.132346     5.517837   14.650182
# 5       ASMR       20         8.933138     0.005102    8.938240
# 6   Outlines       40         9.132346    11.256172   20.388517
# 7       ASMR       40         8.933138     0.008234    8.941372
# 8   Outlines       80         9.132346    22.247808   31.380154
# 9       ASMR       80         8.933138     0.017779    8.950917
# 10  Outlines      160         9.132346    43.143683   52.276028
# 11      ASMR      160         8.933138     0.030442    8.963580
# 12  Outlines      320         9.132346    89.036746   98.169091
# 13      ASMR      320         8.933138     0.053871    8.987009
# ...

# %%
import seaborn as sns

sns.set_style("whitegrid")
ax = sns.lmplot(x="Samples", y="Time", hue="Algorithm",
                 data=evaluation_data, legend = True, legend_out = False, order = 2, ci=None, height = 6)
ax.axes[0,0].set_xlabel("Samples", fontsize = 12)
ax.axes[0,0].set_ylabel("Time", fontsize = 12)
ax.axes[0,0].set_title("Generation + Sample Time", fontsize = 12)
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /home/yoni/miniconda3/envs/py37/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution
# /home/yoni/miniconda3/envs/py37/lib/python3.7/site-packages/seaborn/regression.py:582: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1, 'Generation + Sample Time')

# %%
sns.set_style("whitegrid")

ax = sns.lmplot(x="Samples", y="Sample Time", hue="Algorithm",
                 data=evaluation_data, legend = True, legend_out = False, order = 2, ci=None, height = 6)
ax.axes[0,0].set_xlabel("Samples", fontsize = 12)
ax.axes[0,0].set_ylabel("Time", fontsize = 12)
ax.axes[0,0].set_title("Sample Time", fontsize = 12)
# Out:
# /home/yoni/miniconda3/envs/py37/lib/python3.7/site-packages/seaborn/regression.py:582: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1, 'Sample Time')

# %%
sns.set_style("whitegrid")

ax = sns.lmplot(x="Samples", y="Generation Time", hue="Algorithm",
                 data=evaluation_data, legend = True, legend_out = False, order = 1, ci=None, height = 6)
ax.axes[0,0].set_xlabel("Samples", fontsize = 12)
ax.axes[0,0].set_ylabel("Time", fontsize = 12)
ax.axes[0,0].set_title("Generation Time", fontsize = 12)
# Out:
# /home/yoni/miniconda3/envs/py37/lib/python3.7/site-packages/seaborn/regression.py:582: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1, 'Generation Time')

# %%
truncated_evaluation_data = evaluation_data[evaluation_data['Samples'] < 100]

# %%
truncated_evaluation_data['Time'] = truncated_evaluation_data['Generation Time'] + truncated_evaluation_data['Sample Time']
truncated_evaluation_data
# Out:
# /home/yoni/miniconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#   Algorithm  Samples  Generation Time  Sample Time       Time
# 0  Outlines        5         9.132346     1.753330  10.885675
# 1      ASMR        5         8.933138     0.001611   8.934748
# 2  Outlines       10         9.132346     3.110032  12.242378
# 3      ASMR       10         8.933138     0.002660   8.935797
# 4  Outlines       20         9.132346     5.517837  14.650182
# 5      ASMR       20         8.933138     0.005102   8.938240
# 6  Outlines       40         9.132346    11.256172  20.388517
# ...

# %%
import seaborn as sns

sns.set_style("whitegrid")
ax = sns.lmplot(x="Samples", y="Time", hue="Algorithm",
                 data=truncated_evaluation_data, legend = True, legend_out = False, order = 2, ci=None, height = 6)
ax.axes[0,0].set_xlabel("Samples", fontsize = 12)
ax.axes[0,0].set_ylabel("Time", fontsize = 12)
ax.axes[0,0].set_title("Generation + Sample Time", fontsize = 12)
# Out:
# /home/yoni/miniconda3/envs/py37/lib/python3.7/site-packages/seaborn/regression.py:582: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1, 'Generation + Sample Time')
