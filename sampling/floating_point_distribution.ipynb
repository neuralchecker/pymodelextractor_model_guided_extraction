# %%
import pandas as pd

# %% [markdown]
# # Loading Data

# %%
outlines_data = pd.read_csv('./floating_points_outlines.csv')
outlines_data
# Out:
#       floating-point
# 0           0.767211
# 1           0.691347
# 2           0.379767
# 3           0.992727
# 4           0.718270
# ...              ...
# 9995        0.005407
# 9996        0.251053
# 9997        0.904413
# 9998        0.125271
# 9999        0.687096
#
# [10000 rows x 1 columns]

# %%
asmr_data = pd.read_csv('./floating_points_asmr.csv')
asmr_data
# Out:
#       floating-point
# 0           0.910601
# 1           0.778019
# 2           0.101120
# 3           0.068002
# 4           0.080001
# ...              ...
# 9995        0.270000
# 9996        0.925302
# 9997        0.400018
# 9998        0.800030
# 9999        0.300300
#
# [10000 rows x 1 columns]

# %%
asmr_data_quantized = pd.read_csv('./floating_points_asmr_quantPlus.csv')
asmr_data_quantized
# Out:
#       floating-point
# 0           0.700000
# 1           0.550204
# 2           0.600000
# 3           0.134570
# 4           0.000200
# ...              ...
# 9995        0.064568
# 9996        0.301722
# 9997        0.800100
# 9998        0.844658
# 9999        0.248389
#
# [10000 rows x 1 columns]

# %%
asmr_data_quantized_uniform = pd.read_csv('./floating_points_asmr_quantPlus_Uniform.csv')
asmr_data_quantized_uniform
# Out:
#       floating-point
# 0           0.181100
# 1           0.310404
# 2           0.619231
# 3           0.108002
# 4           0.152117
# ...              ...
# 9995        0.917071
# 9996        0.350013
# 9997        0.611346
# 9998        0.500000
# 9999        0.525000
#
# [10000 rows x 1 columns]

# %%
import seaborn as sns
sns.histplot(outlines_data['floating-point'], bins=10, kde=True)
# Out:
# <Axes: xlabel='floating-point', ylabel='Count'>

# %%
outlines_data_short = pd.read_csv('./floating_points_outlines_short.csv')
outlines_data_short
# Out:
#       floating-point
# 0               0.08
# 1               0.14
# 2               0.55
# 3               0.51
# 4               0.05
# ...              ...
# 9995            0.41
# 9996            0.55
# 9997            0.51
# 9998            0.11
# 9999            0.01
#
# [10000 rows x 1 columns]

# %%
import seaborn as sns
#sns.histplot(outlines_data['floating-point'], bins=10, stat = 'probability', label = 'Outlines')
sns.histplot(outlines_data_short['floating-point'], bins=10, stat = 'probability', label = 'Outlines_Short')
sns.histplot(asmr_data['floating-point'], bins=10, stat = 'probability', label = 'ASMR')

vector_outlines = [0.11623974185039558, 0.21503350436364874, 0.17278691632073126, 0.11030827734764002, 0.08686713808194735, 0.08930311206530712, 0.05253344731556489, 0.05329461757521749, 0.059554999086302525, 0.04407824599324503]

plt.plot([0.05, 0.15, 0.25, 0.35, 0.45, 0.55, 0.65, 0.75, 0.85, 0.95], vector_outlines, label = 'Vector_outlines')

plt.legend()

# %%
vector = [0.14911224109034746, 0.167618143980676, 0.07968686276054647, 0.08318046421449964, 0.09785064397100085, 0.1177426055066604, 0.07556352276936439, 0.09928243209341206, 0.06373532861648695, 0.0662277549970058]
import numpy as np
sum(vector)
print(np.sum(vector))
import matplotlib.pyplot as plt
plt.bar(range(len(vector)), vector)
# Out:
# 1.0
# <BarContainer object of 10 artists>

# %%
import seaborn as sns
sns.histplot(asmr_data_quantized['floating-point'], bins=20, kde=True)
# Out:
# <Axes: xlabel='floating-point', ylabel='Count'>

# %%
import seaborn as sns
sns.histplot(asmr_data_quantized_uniform['floating-point'], bins=20, kde=True)
# Out:
# <Axes: xlabel='floating-point', ylabel='Count'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set style
sns.set(style="whitegrid")

# Plot data
sns.histplot(outlines_data['floating-point'], bins=30, kde=True, color='skyblue', alpha=0.7)
sns.histplot(asmr_data['floating-point'], bins=30, kde=True, color='salmon', alpha=0.7)

# Add labels
plt.xlabel('Floating-point')
plt.ylabel('Count')
plt.title('Distribution of Floating-point Data')

# Add legend
plt.legend(['Outlines', 'ASMR'])

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set style
sns.set(style="whitegrid")

# Plot data
sns.histplot(outlines_data['floating-point'], bins=30, kde=True, color='skyblue', alpha=0.7)
sns.histplot(asmr_data_quantized['floating-point'], bins=30, kde=True, color='salmon', alpha=0.7)

# Add labels
plt.xlabel('Floating-point')
plt.ylabel('Count')
plt.title('Distribution of Floating-point Data')

# Add legend
plt.legend(['Outlines', 'ASMR_Quantized'])

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set style
sns.set(style="whitegrid")

# Plot data
sns.histplot(outlines_data['floating-point'], bins=30, kde=True, color='skyblue', alpha=0.5)
sns.histplot(asmr_data_quantized_uniform['floating-point'], bins=30, kde=True, color='salmon', alpha=0.5)

# Add labels
plt.xlabel('Floating-point')
plt.ylabel('Count')
plt.title('Distribution of Floating-point Data')

# Add legend
plt.legend(['Outlines', 'ASMR_Quantized_Uniform'])

# Show plot
plt.show()

# %%
muestra_outlines = outlines_data["floating-point"].values
muestra_asmr = asmr_data["floating-point"].values

# %%
import numpy as np
import seaborn as sns
from scipy.stats import ks_2samp

# Generar dos muestras de puntos flotantes

# Dibujar gráfico de densidad
sns.kdeplot(muestra_outlines, label='Outlines', color='blue', shade=True)
sns.kdeplot(muestra_asmr, label='ASMR', color='orange', shade=True)

# Calcular el test de Kolmogorov-Smirnov
resultado_ks, p_valor = ks_2samp(muestra_outlines, muestra_asmr)

# Imprimir el resultado del test
print("Estadística de Kolmogorov-Smirnov:", resultado_ks)
print("P-valor:", p_valor)

# Agregar leyenda y mostrar el gráfico
import matplotlib.pyplot as plt
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_5057/3083518320.py:8: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(muestra_outlines, label='Outlines', color='blue', shade=True)
# /tmp/ipykernel_5057/3083518320.py:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(muestra_asmr, label='ASMR', color='orange', shade=True)
# Estadística de Kolmogorov-Smirnov: 0.1327
# P-valor: 4.005607723764709e-77

# %%
from scipy.stats import chisquare
bins = np.linspace(min(min(muestra_outlines), min(muestra_asmr)), max(max(muestra_outlines), max(muestra_asmr)), 20)

# Calcular los histogramas normalizados de las dos muestras
hist1, _ = np.histogram(muestra_outlines, bins=bins, density=True)
hist2, _ = np.histogram(muestra_asmr, bins=bins, density=True)

# Realizar el test de chi cuadrado
estadistico_chi2, p_valor = chisquare(hist1, hist2)

# Imprimir el resultado del test
print("Estadístico Chi-cuadrado:", estadistico_chi2)
print("P-valor:", p_valor)
if p_valor < 0.05:
    print("Se rechaza la hipótesis nula: las distribuciones son diferentes.")
else:
    print("No se rechaza la hipótesis nula: no hay suficiente evidencia para concluir que las distribuciones son diferentes.")
# Out:
# Estadístico Chi-cuadrado: 12.354997594534364
# P-valor: 0.8283783236166653
# No se rechaza la hipótesis nula: no hay suficiente evidencia para concluir que las distribuciones son diferentes.

# %%
muestra_asmr_quantized = asmr_data_quantized["floating-point"].values

# %%
import numpy as np
import seaborn as sns
from scipy.stats import ks_2samp

# Generar dos muestras de puntos flotantes

# Dibujar gráfico de densidad
sns.kdeplot(muestra_outlines, label='Outlines', color='blue', shade=True)
sns.kdeplot(muestra_asmr_quantized, label='ASMR-Quantized', color='orange', shade=True)

# Calcular el test de Kolmogorov-Smirnov
resultado_ks, p_valor = ks_2samp(muestra_outlines, muestra_asmr_quantized)

# Imprimir el resultado del test
print("Estadística de Kolmogorov-Smirnov:", resultado_ks)
print("P-valor:", p_valor)

# Agregar leyenda y mostrar el gráfico
import matplotlib.pyplot as plt
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_5057/1023608963.py:8: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(muestra_outlines, label='Outlines', color='blue', shade=True)
# /tmp/ipykernel_5057/1023608963.py:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(muestra_asmr_quantized, label='ASMR-Quantized', color='orange', shade=True)
# Estadística de Kolmogorov-Smirnov: 0.1377
# P-valor: 4.955867531883539e-83

# %%
from scipy.stats import chisquare
bins = np.linspace(min(min(muestra_outlines), min(muestra_asmr_quantized)), max(max(muestra_outlines), max(muestra_asmr_quantized)), 20)

# Calcular los histogramas normalizados de las dos muestras
hist1, _ = np.histogram(muestra_outlines, bins=bins, density=True)
hist2, _ = np.histogram(muestra_asmr_quantized, bins=bins, density=True)

# Realizar el test de chi cuadrado
estadistico_chi2, p_valor = chisquare(hist1, hist2)

# Imprimir el resultado del test
print("Estadístico Chi-cuadrado:", estadistico_chi2)
print("P-valor:", p_valor)
if p_valor < 0.05:
    print("Se rechaza la hipótesis nula: las distribuciones son diferentes.")
else:
    print("No se rechaza la hipótesis nula: no hay suficiente evidencia para concluir que las distribuciones son diferentes.")
# Out:
# Estadístico Chi-cuadrado: 3.493343281768154
# P-valor: 0.9999122399736419
# No se rechaza la hipótesis nula: no hay suficiente evidencia para concluir que las distribuciones son diferentes.
